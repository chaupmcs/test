# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
tips = sns.load_dataset("tips")

sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);
plt.yticks([2,4,6,8, 10], [2,4,60, 80, 1000])
# Out:
# ([<matplotlib.axis.YTick at 0x7fa8d1549810>,
#   <matplotlib.axis.YTick at 0x7fa8d1364850>,
#   <matplotlib.axis.YTick at 0x7fa8d13c97d0>,
#   <matplotlib.axis.YTick at 0x7fa8d16ae6d0>,
#   <matplotlib.axis.YTick at 0x7fa8d16b64d0>],
#  <a list of 5 Text yticklabel objects>)
